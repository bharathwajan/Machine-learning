# %%
import os
import tensorflow as tf 
from tensorflow import keras
import cv2
import random
import matplotlib.pyplot as plt
import numpy as np
import pickle

# %%
dir='C:/Users/rbw19/Downloads/kagglecatsanddogs_3367a/PetImages'
catagories=['dog','cat']
data=[]

# %%
for i in catagories:
    folder=os.path.join(dir,i)
    print(folder)
    for img in os.listdir(folder):
        img_path=os.path.join(folder,img)
        print(img_path)
        if img_path=='C:/Users/rbw19/Downloads/kagglecatsanddogs_3367a/PetImages\Dog\Thumbs.db':
            print('neglected dump file')
        elif img_path=='C:/Users/rbw19/Downloads/kagglecatsanddogs_3367a/PetImages\Cat\Thumbs.db':
            print('neglected dump file')
        else:
            img_arr=cv2.imread(img_path)
            try:
                img_arr=cv2.resize(img_arr,(120,120))
                data.append([img_arr,catagories.index(i)])
            except:
                print('one image excluded')
# Out:
# C:/Users/rbw19/Downloads/kagglecatsanddogs_3367a/PetImages\dog
# C:/Users/rbw19/Downloads/kagglecatsanddogs_3367a/PetImages\dog\0.jpg
# C:/Users/rbw19/Downloads/kagglecatsanddogs_3367a/PetImages\dog\1.jpg
# C:/Users/rbw19/Downloads/kagglecatsanddogs_3367a/PetImages\dog\10.jpg
# C:/Users/rbw19/Downloads/kagglecatsanddogs_3367a/PetImages\dog\100.jpg
# C:/Users/rbw19/Downloads/kagglecatsanddogs_3367a/PetImages\dog\1000.jpg
# C:/Users/rbw19/Downloads/kagglecatsanddogs_3367a/PetImages\dog\10000.jpg
# C:/Users/rbw19/Downloads/kagglecatsanddogs_3367a/PetImages\dog\10001.jpg
# C:/Users/rbw19/Downloads/kagglecatsanddogs_3367a/PetImages\dog\10002.jpg
# C:/Users/rbw19/Downloads/kagglecatsanddogs_3367a/PetImages\dog\10003.jpg
# C:/Users/rbw19/Downloads/kagglecatsanddogs_3367a/PetImages\dog\10004.jpg
# C:/Users/rbw19/Downloads/kagglecatsanddogs_3367a/PetImages\dog\10005.jpg
# C:/Users/rbw19/Downloads/kagglecatsanddogs_3367a/PetImages\dog\10006.jpg
# ...

# %%
print(len(data))
random.shuffle(x)
x=[]
y=[]
# Out:
# 24946

# %%
for catagories,labels in data:
    x.append(catagories)
    y.append(labels)
print(len(x))
print(len(y))
# Out:
# 24946
# 24946

# %%
samples=np.array(x)
labels=np.array(y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-cb032eb412a4> in <module>
# ----> 1 samples=np.array(x)
#       2 labels=np.array(y)
#
# NameError: name 'np' is not defined

# %%
print(samples[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e139d330c55c> in <module>
# ----> 1 print(samples[0])
#
# NameError: name 'samples' is not defined

# %%
print(len(samples))
print(len(labels ))
# Out:
# 24946
# 24946

# %%
pickle.dump(samples,open('samples.pkl','wb'))
pickle.dump(labels,open('labels.pkl','wb'))
